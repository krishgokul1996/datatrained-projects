# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("happiness_score_dataset.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
columns = ['Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
fig,ax = plt.subplots(5,2,figsize=(20,20))
row = col = 0
for n,i in enumerate(columns):
    if (n%2 == 0) & (n > 0):
        row += 1
        col = 0
    sn.distplot(df[i],kde=True,ax=ax[row,col])
    col += 1

# %%
fig,ax = plt.subplots(5,2,figsize=(20,20))
row = col = 0
for n,i in enumerate(columns):
    if (n%2 == 0) & (n > 0):
        row += 1
        col = 0
    sn.boxplot(df[i],ax=ax[row,col])
    col += 1

# %%
plt.figure(figsize=[10,6])
plt.title("Comparision between Economy and Happiness Score")
sn.scatterplot(df['Economy (GDP per Capita)'],df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Economy and Happiness Score'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=[10,6])
plt.title("Comparision between Health and Happiness Score")
sn.scatterplot(df['Health (Life Expectancy)'],df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Health and Happiness Score'}, xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=[10,6])
plt.title("Comparision between Freedom and Happiness Score")
sn.scatterplot(df['Freedom'],df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Freedom and Happiness Score'}, xlabel='Freedom', ylabel='Happiness Score'>

# %%
plt.figure(figsize=[10,6])
plt.title("Comparision between Trust on Government and Happiness Score")
sn.scatterplot(df['Trust (Government Corruption)'],df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Trust on Government and Happiness Score'}, xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
cor=df.corr()
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sn.pairplot(df)

# %%
plt.figure(figsize=(10,10))
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,7))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color ='c')
# Out:
# <AxesSubplot:>

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Region']=label.fit_transform(df['Region'])
df.head()
# Out:
#        Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland       9               1            7.587         0.03411
# 1      Iceland       9               2            7.561         0.04884
# 2      Denmark       9               3            7.527         0.03328
# 3       Norway       9               4            7.522         0.03880
# 4       Canada       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
df.drop(['Happiness Rank'],axis=1, inplace = True)
df.drop(['Country'],axis=1, inplace = True)
df.head()
# Out:
#    Region  Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9            7.587         0.03411                   1.39651  1.34951
# 1       9            7.561         0.04884                   1.30232  1.40223
# 2       9            7.527         0.03328                   1.32548  1.36058
# 3       9            7.522         0.03880                   1.45900  1.33095
# 4       5            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# ...

# %%
Q1 = df['Trust (Government Corruption)'].quantile(0.25)
Q3 = df['Trust (Government Corruption)'].quantile(0.75)
IQR = Q3 - Q1
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR
df_iqr = df[(df['Trust (Government Corruption)']>lower_lim)&(df['Trust (Government Corruption)']<upper_lim)]
df_iqr.shape
# Out:
# (144, 10)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
df_zscore=df[(z<3).all(axis=1)]
df_zscore.shape
# Out:
# (149, 10)

# %%
df_zscore.describe()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# count  149.000000       149.000000      149.000000                149.000000
# mean     5.080537         5.429611        0.046241                  0.862163
# std      3.032519         1.111256        0.014043                  0.387975
# min      0.000000         2.905000        0.018480                  0.000000
# 25%      3.000000         4.610000        0.036800                  0.593250
# 50%      4.000000         5.268000        0.043610                  0.920490
# 75%      8.000000         6.295000        0.050690                  1.159910
# max      9.000000         7.587000        0.098110                  1.563910
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  149.000000                149.000000  149.000000
# mean     1.008623                  0.638624    0.427449
# std      0.251890                  0.245937    0.150864
# ...

# %%
df_zscore.skew()
# Out:
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
columns = ['Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Dystopia Residual']
fig,ax = plt.subplots(3,3,figsize=(20,20))
row = col = 0
for n,i in enumerate(columns):
    if (n%3 == 0) & (n > 0):
        row += 1
        col = 0
    sn.distplot(df_zscore[i],ax=ax[row,col])
    col += 1

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df_zscore)
df_zscore=pd.DataFrame(dfpt,columns=df_zscore.columns)
df_zscore.skew()
# Out:
# Region                          -0.222589
# Happiness Score                 -0.017940
# Standard Error                  -0.031216
# Economy (GDP per Capita)        -0.140644
# Family                          -0.148528
# Health (Life Expectancy)        -0.190663
# Freedom                         -0.076489
# Trust (Government Corruption)    0.174593
# Generosity                       0.025172
# Dystopia Residual                0.014748
# dtype: float64

# %%
fig,ax = plt.subplots(3,3,figsize=(20,20))
row = col = 0
for n,i in enumerate(columns):
    if (n%3 == 0) & (n > 0):
        row += 1
        col = 0
    sn.distplot(df_zscore[i],ax=ax[row,col])
    col += 1

# %%
fig,ax = plt.subplots(3,3,figsize=(20,20))
row = col = 0
for n,i in enumerate(columns):
    if (n%3 == 0) & (n > 0):
        row += 1
        col = 0
    sn.boxplot(df_zscore[i],ax=ax[row,col])
    col += 1

# %%
y = df_zscore['Happiness Score']
x = df_zscore
x.drop('Happiness Score',axis = 1, inplace = True)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 1.23451354, -0.95033703,  1.49245411, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [ 1.23451354,  0.37856182,  1.19406711, ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [ 1.23451354, -1.04140135,  1.26661161, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [ 0.66673577, -1.32081011, -1.36521585, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [ 0.95527966, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 0.95527966,  2.17876604, -1.93874732, ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x_scaled,y,test_size=0.25,random_state=42)
xtest.shape
# Out:
# (38, 9)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lm.score(xtest,ytest)
# Out:
# 0.9934327035848279

# %%
ypred_lr = lm.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

r2=r2_score(ytest,ypred_lr)
mae=mean_absolute_error(ypred_lr,ytest)
mse=mean_squared_error(ypred_lr,ytest)
rmse=np.sqrt(mean_squared_error(ypred_lr,ytest))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.9934327035848279
# Mean absolute error =  0.06256158282912044
# Mean Squared error =  0.0060550126382131995
# Root Mean Sqaured Error=  0.07781396171776116

# %%
cv_score = cross_val_score(lm,x_scaled,y,cv=3)
cv_mean = cv_score.mean()
cv_mean

# %%
from sklearn.tree import DecisionTreeRegressor 
  

dtr = DecisionTreeRegressor(random_state = 23)   
dtr.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(random_state=23)

# %%
dtr.score(xtrain,ytrain)
# Out:
# 1.0

# %%
dtr.score(xtest,ytest)
# Out:
# 0.8440142777076245

# %%
ypred_dtr = dtr.predict(xtest)

# %%
r2=r2_score(ytest,ypred_dtr)
mae=mean_absolute_error(ypred_dtr,ytest)
mse=mean_squared_error(ypred_dtr,ytest)
rmse=np.sqrt(mean_squared_error(ypred_dtr,ytest))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.8440142777076245
# Mean absolute error =  0.3007466486228178
# Mean Squared error =  0.14381801279429504
# Root Mean Sqaured Error=  0.3792334542129624

# %%
cv_score = cross_val_score(dtr,x,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-71f1d734909d> in <module>
# ----> 1 cv_score = cross_val_score(dtr,x,y,cv=5)
#       2 cv_mean = cv_score.mean()
#       3 cv_mean
#
# NameError: name 'cross_val_score' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor
  
rfr = RandomForestRegressor(n_estimators = 100, random_state = 12)
rfr.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(random_state=12)

# %%
rfr.score(xtrain,ytrain)
# Out:
# 0.9842007228424355

# %%
rfr.score(xtest,ytest)
# Out:
# 0.9115407969523721

# %%
ypred_rfr = rfr.predict(xtest)

# %%
r2=r2_score(ytest,ypred_rfr)
mae=mean_absolute_error(ypred_rfr,ytest)
mse=mean_squared_error(ypred_rfr,ytest)
rmse=np.sqrt(mean_squared_error(ypred_rfr,ytest))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.9115407969523721
# Mean absolute error =  0.20052770624004415
# Mean Squared error =  0.08155891839787145
# Root Mean Sqaured Error=  0.28558522090239796

# %%
from sklearn.neighbors import KNeighborsRegressor

knr= KNeighborsRegressor(n_neighbors=3)
knr.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knr.score(xtrain,ytrain)
# Out:
# 0.9227184199983497

# %%
knr.score(xtest,ytest)
# Out:
# 0.8982407960409696

# %%
ypred_knr = knr.predict(xtest)

# %%
r2=r2_score(ytest,ypred_knr)
mae=mean_absolute_error(ypred_knr,ytest)
mse=mean_squared_error(ypred_knr,ytest)
rmse=np.sqrt(mean_squared_error(ypred_knr,ytest))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.8982407960409696
# Mean absolute error =  0.2519937426039771
# Mean Squared error =  0.09382144905215113
# Root Mean Sqaured Error=  0.30630287143961143

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

cv_score = cross_val_score(lm,x_scaled,y,cv=3)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.6567134860441489

# %%
cv_score2 = cross_val_score(dtr,x_scaled,y,cv=5)
cv_mean2 = cv_score2.mean()
cv_mean2
# Out:
# -7.240783954137706

# %%
cv_score3 = cross_val_score(rfr,x_scaled,y,cv=5)
cv_mean3 = cv_score3.mean()
cv_mean3
# Out:
# -3.66123642439718

# %%
cv_score4 = cross_val_score(knr,x_scaled,y,cv=5)
cv_mean4 = cv_score4.mean()
cv_mean4
# Out:
# -5.797534611685232

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

parameters = {'alpha': [.0001,.001,.01,.1,1,10], 'random_state': list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(xtrain,ytrain)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls = Lasso(alpha= 0.001,random_state= 0)
ls.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=0.001, random_state=0)

# %%
ls.score(xtrain,ytrain)
# Out:
# 0.9884887287726635

# %%
ypred_ls = ls.predict(xtest)
r2 = r2_score(ytest,ypred_ls)
r2
# Out:
# 0.9935939038489889

# %%
cv_score = cross_val_score(ls,x_scaled,y,cv=3)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.6651781912720488

# %%
parameters = { 'fit_intercept' : ['True','False'],
               'normalize' : ['True','False'],
               'n_jobs' : [-5,1,10,100]
             }
GCV = GridSearchCV(LinearRegression(),parameters,cv =3)
GCV.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=3, estimator=LinearRegression(),
#              param_grid={'fit_intercept': ['True', 'False'],
#                          'n_jobs': [-5, 1, 10, 100],
#                          'normalize': ['True', 'False']})

# %%
GCV.best_params_
# Out:
# {'fit_intercept': 'True', 'n_jobs': -5, 'normalize': 'True'}

# %%
Final_mod = LinearRegression(fit_intercept= 'True', n_jobs= -5 , normalize= 'True')
Final_mod.fit(xtrain,ytrain)
ypred_final = Final_mod.predict(xtest)
r2=r2_score(ytest,ypred_final)
r2
# Out:
# 0.9934327035848278

# %%
cv_score = cross_val_score(Final_mod,x_scaled,y,cv=3)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.6567134860441478
