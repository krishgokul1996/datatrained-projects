# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the train data set
df= pd.read_csv("bigdatamart_Train.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# The dataset has 8523 observations and 12 columns

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df['Item_Fat_Content'].replace(['low fat','Low Fat','reg'],['LF','LF','Regular'],inplace = True)

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['LF', 'Regular'], dtype=object)

# %%
sn.distplot(df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sn.distplot(df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sn.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sn.boxplot(df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %%
sn.boxplot(df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
sn.boxplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
sn.pairplot(df, hue = "Item_Fat_Content")

# %%
plt.figure(figsize=[10,6])
plt.title("Sales based on Item visibility")
sn.scatterplot(df['Item_Visibility'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:title={'center':'Sales based on Item visibility'}, xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=[10,6])
plt.title("Sales based on Item visibility")
sn.scatterplot(df['Item_MRP'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:title={'center':'Sales based on Item visibility'}, xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
sn.countplot(x="Outlet_Location_Type", data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sn.countplot(x="Item_Fat_Content", data = df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
sn.countplot(x="Outlet_Size", data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
cor=df.corr()
cor=df.corr()
plt.figure(figsize=(10,5))
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
Q1 = df['Item_Visibility'].quantile(0.25)
Q3 = df['Item_Visibility'].quantile(0.75)
IQR = Q3 - Q1
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR
df_iqr = df[(df['Item_Visibility']>lower_lim)&(df['Item_Visibility']<upper_lim)]
df_iqr.shape
# Out:
# (8379, 12)

# %%
sn.boxplot(df_iqr['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
Q1 = df['Item_Outlet_Sales'].quantile(0.25)
Q3 = df['Item_Outlet_Sales'].quantile(0.75)
IQR = Q3 - Q1
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR
df_iqr = df[(df['Item_Outlet_Sales']>lower_lim)&(df['Item_Outlet_Sales']<upper_lim)]
df_iqr.shape
# Out:
# (8337, 12)

# %%
sn.boxplot(df_iqr['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
df_iqr.skew()
# Out:
# Item_Weight                  0.088656
# Item_Visibility              1.164554
# Item_MRP                     0.149206
# Outlet_Establishment_Year   -0.419174
# Item_Outlet_Sales            0.780104
# dtype: float64

# %%
df_iqr.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# We can see that the sales is not depending on the values of Item_Identifier, Outlet_Identifier.
# So we can get rid of these columns.

# %%
new_df = df_iqr.drop(columns=[ 'Item_Identifier', 'Outlet_Identifier','Outlet_Establishment_Year',])
new_df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30               LF         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50               LF         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93               LF         0.000000              Household
#
#    Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0  249.8092      Medium               Tier 1  Supermarket Type1
# 1   48.2692      Medium               Tier 3  Supermarket Type2
# 2  141.6180      Medium               Tier 1  Supermarket Type1
# 3  182.0950      Medium               Tier 3      Grocery Store
# 4   53.8614        High               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
from sklearn.preprocessing import LabelEncoder
columns = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
le = LabelEncoder()
for i in columns:
    new_df[i] = le.fit_transform(new_df[i])
new_df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.000000          6  182.0950
# 4         8.93                 0         0.000000          9   53.8614
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0            1                     0            1          3735.1380
# 1            1                     2            2           443.4228
# 2            1                     0            1          2097.2700
# 3            1                     2            0           732.3800
# 4            0                     2            1           994.7052

# %%
new_df.skew()
# Out:
# Item_Weight             0.088656
# Item_Fat_Content        0.615277
# Item_Visibility         1.164554
# Item_Type               0.099195
# Item_MRP                0.149206
# Outlet_Size            -0.094885
# Outlet_Location_Type   -0.191149
# Outlet_Type             0.938833
# Item_Outlet_Sales       0.780104
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(new_df)
new_df=pd.DataFrame(dfpt,columns=new_df.columns)

# %%
new_df.skew()
# Out:
# Item_Weight            -0.069790
# Item_Fat_Content        0.615277
# Item_Visibility         0.125418
# Item_Type              -0.165775
# Item_MRP               -0.110207
# Outlet_Size            -0.046309
# Outlet_Location_Type   -0.213048
# Outlet_Type             0.009922
# Item_Outlet_Sales      -0.108960
# dtype: float64

# %% [markdown]
# We can see that the Item_Visibility skewness is now removed and since Item_Fat_Content is a categorical variabe we will not try to remove its skewness

# %%
y = new_df['Item_Outlet_Sales']
X= new_df.drop(columns=['Item_Outlet_Sales'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.81677899, -0.73865163, -1.14697856, ..., -0.29731455,
#         -1.36604292, -0.10502991],
#        [-1.72424714,  1.35381817, -1.03756748, ..., -0.29731455,
#          1.09692448,  1.07748307],
#        [ 1.0806394 , -0.73865163, -1.12255121, ..., -0.29731455,
#         -1.36604292, -0.10502991],
#        ...,
#        [-0.49234732, -0.73865163, -0.54505272, ...,  1.38192872,
#         -0.11256678, -0.10502991],
#        [-1.36517661,  1.35381817,  1.4532839 , ..., -0.29731455,
#          1.09692448,  1.07748307],
#        [ 0.49013322, -0.73865163, -0.2790742 , ...,  1.38192872,
#         -1.36604292, -0.10502991]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
lr = LinearRegression()
lr.fit(X_train,y_train)
pred= lr.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.5758163560918683
# Mean absolute error =  0.5082505818960708
# Mean Squared error =  0.4152281692204012
# Root Mean Sqaured Error=  0.6443820056615495

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score = cross_val_score(lr,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.5946306510128447

# %%
from sklearn.tree import DecisionTreeRegressor 
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)
pred= dtr.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.29026855773928417
# Mean absolute error =  0.6375044130165232
# Mean Squared error =  0.6947474086763639
# Root Mean Sqaured Error=  0.8335150920507461

# %%
cv_score = cross_val_score(dtr,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.3305469901639917

# %%
from sklearn.ensemble import RandomForestRegressor
  
rfr = RandomForestRegressor(n_estimators = 100, random_state = 12)
rfr.fit(X_train, y_train) 
pred= rfr.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.6143932043495263
# Mean absolute error =  0.47515679516735504
# Mean Squared error =  0.37746576535036963
# Root Mean Sqaured Error=  0.6143824259778022

# %%
cv_score = cross_val_score(rfr,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.6292978590881467

# %%
 from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(X_train, y_train) 
pred= knr.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.5521284525905346
# Mean absolute error =  0.5199448462373554
# Mean Squared error =  0.43841596758270346
# Root Mean Sqaured Error=  0.6621298721419412

# %%
cv_score = cross_val_score(knr,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.5639400900828326

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha= 0.001,random_state= 0)
ridge.fit(X_train, y_train) 
pred= ridge.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.5758163650997024
# Mean absolute error =  0.508250579307472
# Mean Squared error =  0.41522816040274296
# Root Mean Sqaured Error=  0.6443819988196

# %%
cv_score = cross_val_score(ridge,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.5946306515905782

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha= 0.1,random_state= 0)
lasso.fit(X_train, y_train) 
pred= lasso.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.5324722611860933
# Mean absolute error =  0.5470158400262798
# Mean Squared error =  0.4576571723955878
# Root Mean Sqaured Error=  0.6765036381244286

# %%
cv_score = cross_val_score(lasso,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.5376246895875422

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\sumuk\anaconda3\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy in c:\users\sumuk\anaconda3\lib\site-packages (from xgboost) (1.5.2)
# Requirement already satisfied: numpy in c:\users\sumuk\anaconda3\lib\site-packages (from xgboost) (1.19.2)

# %%
from xgboost.sklearn import XGBRegressor
XGB = XGBRegressor()
XGB.fit(X_train, y_train)
pred = XGB.predict(X_test)
r2=r2_score(y_test,pred)
mae=mean_absolute_error(pred,y_test)
mse=mean_squared_error(pred,y_test)
rmse=np.sqrt(mean_squared_error(pred,y_test))
print('r2score=',r2)
print('Mean absolute error = ',mae)
print('Mean Squared error = ',mse)
print('Root Mean Sqaured Error= ',rmse)
# Out:
# r2score= 0.6181209781213175
# Mean absolute error =  0.4723035899660231
# Mean Squared error =  0.3738166933016041
# Root Mean Sqaured Error=  0.6114055064370979

# %%
cv_score = cross_val_score(XGB,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.6300684726170583

# %% [markdown]
# Watching all the above data we can see that the minimum difference between r2 score cv score is for the XGB Regressor.
# Hence that is our best performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = { 
             'max_depth' : np.arange(2,10),
             'eta' : [0.01,0.1,0.2,0.3],
             'alpha' : [0,0.1,1,10]
             }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,cv =5)

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'alpha': [0, 0.1, 1, 10], 'eta': [0.01, 0.1, 0.2, 0.3],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_
# Out:
# {'alpha': 1, 'eta': 0.1, 'max_depth': 2}

# %%
Final_mod = XGBRegressor(alpha=1,eta=0.1,max_depth = 2)
Final_mod.fit(X_train,y_train)
pred = Final_mod.predict(X_test)
r2=r2_score(y_test,pred)
cv_score = cross_val_score(Final_mod,X_scaled,y,cv=5)
cv_mean = cv_score.mean()
print(r2,cv_mean)
# Out:
# 0.6626850535142235 0.6816117713956046

# %% [markdown]
# We see that the r2 score has improved after Hyper parameter tuning

# %% [markdown]
# <b>Serialization<b>

# %%
#Saving the model
import joblib
joblib.dump(Final_mod,"BigDataMart.pkl")
# Out:
# ['BigDataMart.pkl']

# %%
#Importing the test data set
df_test= pd.read_csv("bigdatamart_Test.csv")
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df_test.nunique()
# Out:
# Item_Identifier              1543
# Item_Weight                   410
# Item_Fat_Content                5
# Item_Visibility              5277
# Item_Type                      16
# Item_MRP                     4402
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# dtype: int64

# %%
df_test['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Grocery Store', 'Supermarket Type3',
#        'Supermarket Type2'], dtype=object)

# %% [markdown]
# We see that even in the test there are four types of outlet.

# %%
df_test.shape
# Out:
# (5681, 11)

# %% [markdown]
# There are 5681 rows and 11 columns

# %%
df_test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# We see that there are missing values under Outlest size and Item weight

# %%
df_test['Item_Weight'] = df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean())
df_test['Outlet_Size'] = df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0])
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# We can now see that all the missing values have been imputed

# %%
df_test['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
df_test['Item_Fat_Content'].replace(['low fat','Low Fat','reg'],['LF','LF','Regular'],inplace = True)

# %%
df_test['Item_Fat_Content'].unique()
# Out:
# array(['LF', 'Regular'], dtype=object)

# %% [markdown]
# We have replaced the mispelled words with the same word for Item_Fat_Content

# %%
df_test.skew()
# Out:
# Item_Weight                  0.142813
# Item_Visibility              1.238312
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
columns = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
le = LabelEncoder()
for i in columns:
    df_test[i] = le.fit_transform(df_test[i])
df_test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58    20.750000                 0         0.007565         13
# 1           FDW14     8.300000                 1         0.038428          4
# 2           NCN55    14.600000                 0         0.099575         11
# 3           FDQ58     7.315000                 0         0.015388         13
# 4           FDY38    12.695633                 1         0.118599          4
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622            OUT049                       1999            1
# 1   87.3198            OUT017                       2007            1
# 2  241.7538            OUT010                       1998            1
# 3  155.0340            OUT017                       2007            1
# 4  234.2300            OUT027                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %%
df_test = df_test.drop(columns=[ 'Item_Identifier', 'Outlet_Identifier','Outlet_Establishment_Year',])

# %%
df_test.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0    20.750000                 0         0.007565         13  107.8622
# 1     8.300000                 1         0.038428          4   87.3198
# 2    14.600000                 0         0.099575         11  241.7538
# 3     7.315000                 0         0.015388         13  155.0340
# 4    12.695633                 1         0.118599          4  234.2300
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0            1                     0            1
# 1            1                     1            1
# 2            1                     2            0
# 3            1                     1            1
# 4            1                     2            3

# %%
pt=PowerTransformer()
dfpt=pt.fit_transform(df_test)
df_test=pd.DataFrame(dfpt,columns=df_test.columns)

# %%
df_test.skew()
# Out:
# Item_Weight            -0.060915
# Item_Fat_Content        0.609223
# Item_Visibility         0.116776
# Item_Type              -0.167431
# Item_MRP               -0.111040
# Outlet_Size            -0.042981
# Outlet_Location_Type   -0.220642
# Outlet_Type             0.007830
# dtype: float64

# %% [markdown]
# The skewness of Item visibility is still high

# %%
scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_test)
df_test_scaled
# Out:
# array([[ 1.77007392, -0.74081066, -1.46206861, ..., -0.29345691,
#         -1.37374464, -0.12353311],
#        [-1.03619283,  1.34987258, -0.44801894, ..., -0.29345691,
#         -0.13101959, -0.12353311],
#        [ 0.49167513, -0.74081066,  0.87134242, ..., -0.29345691,
#          1.08829997, -1.91575348],
#        ...,
#        [-0.59355557, -0.74081066,  0.39786781, ..., -0.29345691,
#         -0.13101959, -0.12353311],
#        [ 0.64562931,  1.34987258, -1.76023409, ..., -0.29345691,
#         -0.13101959, -0.12353311],
#        [-0.72091914,  1.34987258,  0.9524881 , ..., -0.29345691,
#         -0.13101959, -0.12353311]])

# %%
prediction_test = Final_mod.predict(df_test)
prediction_test
# Out:
# array([-0.15423155, -0.33054778, -1.1115382 , ...,  0.03972046,
#         0.8710896 , -0.3640477 ], dtype=float32)
